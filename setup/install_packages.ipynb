# %%
# Databricks notebook source
# DBTITLE 1,Install Required Packages
# %pip install langchain-community langchain-core langchain-databricks openai anthropic pydantic -q

# %%
pip install langchain_community
